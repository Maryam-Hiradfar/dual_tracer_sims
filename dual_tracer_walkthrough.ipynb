# %% [markdown]
# # Week 1: Simulating PET Time–Activity Curves from Ground Truth to Noisy Measurements
#
# In this notebook, we will build intuition for how PET measurements arise from tracer kinetics.
#
# We will walk through:
#
# 1. Generating a single-tracer ground-truth TAC
# 2. Generating a dual-tracer ground-truth TAC
# 3. Defining PET measurement frames
# 4. Converting activity into expected counts
# 5. Adding Poisson noise to simulate measured PET data
